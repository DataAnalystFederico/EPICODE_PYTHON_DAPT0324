# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pandas as pd

dbname = "AdventureWorksDW"
username = 'studente_dapt'
port = "3306"
password = 'Ep1c0d3!!D4t4**4n4lys1s'
host = 'epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com'
conn_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
db_engine = create_engine(conn_string)
query = """SELECT *
        FROM dimproduct
        """
df = pd.read_sql(query, db_engine)
df
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
# task 1:
'''Estraiamo la tabella dimproduct dal database AdventureWorks, e valutiamo quanto segue: 
• Quanti dati ci sono in totale?'''

df.shape
# df.info()
# Out:
# (606, 36)

# %%
# task 2:
'''Quali sono i metadati?'''

df.info()
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
# task 3:
'''• Stampiamo il primo elemento'''

df.head(1)
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# 0                  None                None    Adjustable Race
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
#
# [1 rows x 36 columns]

# %%
# task 4:
'''• Stampiamo l'ultimo elemento'''

df.tail(1)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# ...

# %%
# task 5:
'''• Riusciamo a stampare cinque elementi a caso?'''

df.sample(5)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 516         517             SE-M940                   15.0
# 287         288          FR-M94S-42                   12.0
# 595         596          BK-M18B-40                    1.0
# 25           26             FW-3800                    NaN
# 228         229           LJ-0192-M                   21.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode              EnglishProductName  \
# 516                  None                None         HL Mountain Seat/Saddle
# 287                    LB                  CM  HL Mountain Frame - Silver, 42
# 595                    LB                  CM          Mountain-500 Black, 40
# 25                   None                None                   Flat Washer 4
# 228                  None                None      Long-Sleeve Logo Jersey, M
#
#                         SpanishProductName  \
# 516
# 287
# 595                Montaña: 500, negra, 40
# 25
# ...

# %%
# task 6:
'''• Quali sono i colori disponibili?'''

df['Color'].value_counts() # df['Color'].unique()
# Out:
# Color
# NA              254
# Black           133
# Red              63
# Silver           52
# Yellow           46
# Blue             28
# Multi            18
# Silver/Black      7
# White             4
# Grey              1
# Name: count, dtype: int64

# %%
# task 7:
'''In media quanto pesano i prodotti?'''

df['Weight'].mean()
# Out:
# 56.1932269503546

# %%
# task 8:
'''Quanto pesa il più leggero?'''

df['Weight'].min()
# Out:
# 2.12

# %%
# task 8:
'''Quanto pesa il più pesante?'''

df['Weight'].max()
# Out:
# 1050.0

# %%
# task 9:
'''Quanti prodotti pesano più di 100 Kg?'''

import numpy as np

maggiori_di_100 = df[df['Weight']>100]
maggiori_di_100[['EnglishProductName']].count()
df.loc[:,'Weight']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 601    168.00
# 602    170.00
# 603     19.77
# 604     20.13
# 605     20.42
# Name: Weight, Length: 606, dtype: float64

# %%
# task 10:
'''• Quanto costano in media i prodotti (colonna DealerPrice)?'''

df['DealerPrice'].mean()
# Out:
# 448.5970597468353

# %%
# task 11:
'''• Se prendiamo un quarto di tutti i prodotti, in modo che siano i più costosi, quale sarà il loro range di prezzo?'''

df['EnglishProductName'].nunique()
quarto_alto = df.sort_values(by='DealerPrice', ascending=False).head(126)
media_quarto_alto = quarto_alto['DealerPrice'].mean()
media_quarto_alto
quarto_alto[['EnglishProductName','DealerPrice']].head(30) # vedere i 30 prodotti più costosi
# Out:
# 1055.7442031746034

# %%
# task 12:
'''• Qual è il prezzo medio per i prodotti di colore blu?'''

colori_blu = df[df['Color'] == 'Blue']
colori_blu[['ListPrice']].mean()
# Out:
# ListPrice    860.105
# dtype: float64

# %%
# task 13:
'''• Qual è il prezzo medio per i prodotti di colore rosso o nero?'''

colori_rosso_nero = df[(df['Color'] == 'Red') | (df['Color'] == 'Black')]
colori_rosso_nero['ListPrice'].mean()
# Out:
# 917.08

# %%
# task 14:
'''• Qual è il prezzo massimo per i prodotti di taglia 42 e peso oltre i 10 Kg?'''

prodotti_taglia_peso_filtrati = df[(df['Size'] == '42') & (df['Weight'] > 10)]
prodotti_taglia_peso_filtrati['ListPrice'].max()
# Out:
# 3399.99

# %%
# task 15:
'''Qual è il nome inglese e il costo di produzione 
(StandardCost) di tutti i prodotti di taglia 42, peso oltre i 10 Kg e colore argento?'''

prodotti_taglia_peso_colore_filtrati = df[(df['Size'] == '42') & (df['Weight'] > 10) & (df['Color'] == 'Silver')]
prodotti_taglia_peso_colore_filtrati[['EnglishProductName','StandardCost']]
# Out:
#             EnglishProductName  StandardCost
# 344    Mountain-100 Silver, 42       1912.15
# 353    Mountain-200 Silver, 42       1117.86
# 354    Mountain-200 Silver, 42       1265.62
# 588  Mountain-400-W Silver, 42        419.78
# 591    Mountain-500 Silver, 42        308.22

# %%
# task 16:
'''Esaminiamo la differenza tra lo StandardCost e il DealerPrice 
degli ultimi 20 elementi del dataset:

c'è un pattern? si
C'è qualche elemento che non lo segue? gli ultimi 3 hanno il prezzo di listino inferiore'''

df[['StandardCost','DealerPrice']].tail(20)
# Out:
#      StandardCost  DealerPrice
# 586        419.78      461.694
# 587        419.78      461.694
# 588        419.78      461.694
# 589        419.78      461.694
# 590        308.22      338.994
# 591        308.22      338.994
# 592        308.22      338.994
# 593        308.22      338.994
# 594        308.22      338.994
# 595        294.58      323.994
# 596        294.58      323.994
# 597        294.58      323.994
# 598        294.58      323.994
# 599        294.58      323.994
# 600         23.97       32.394
# 601         44.95       60.744
# 602         53.94       72.894
# 603        343.65      323.994
# 604        343.65      323.994
# 605        343.65      323.994
